# %%
import pandas as pd
import numpy as np
import re
import spacy
from tqdm import tqdm

# %%
nlp = spacy.load("en_core_web_sm")
print("spaCy loaded")
# Out:
# spaCy loaded

# %%
go = pd.read_csv("../data/raw/goemotions.csv")
reddit = pd.read_csv("../data/raw/reddit_mental_health.csv")
emotion = pd.read_csv("../data/raw/emotion.csv")

print(go.shape)
print(reddit.shape)
print(emotion.shape)
# Out:
# (54263, 3)
# (16084, 1)
# (16000, 2)

# %%
go = go[["text"]]
reddit = reddit[["text"]]
emotion = emotion[["text"]]

combined = pd.concat([go, reddit, emotion], ignore_index=True)

print("Combined shape:", combined.shape)
combined.head()
# Out:
# Combined shape: (86347, 1)
#                                                 text
# 0  My favourite food is anything I didn't have to...
# 1  Now if he does off himself, everyone will thin...
# 2                     WHY THE FUCK IS BAYLESS ISOING
# 3                        To make her feel threatened
# 4                             Dirty Southern Wankers

# %%
def clean_text(text):
    text = str(text).lower()

    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"www\S+", "", text)

    text = re.sub(r"@\w+", "", text)
    text = re.sub(r"#\w+", "", text)

    text = re.sub(r"[^a-zA-Z\s]", " ", text)

    text = re.sub(r"\s+", " ", text).strip()

    return text

# %%
tqdm.pandas()

combined["clean_text"] = combined["text"].progress_apply(clean_text)

combined.head()
# Out:
# 100%|██████████| 86347/86347 [00:00<00:00, 124451.42it/s]
#                                                 text  \
# 0  My favourite food is anything I didn't have to...
# 1  Now if he does off himself, everyone will thin...
# 2                     WHY THE FUCK IS BAYLESS ISOING
# 3                        To make her feel threatened
# 4                             Dirty Southern Wankers
#
#                                           clean_text
# 0  my favourite food is anything i didn t have to...
# 1  now if he does off himself everyone will think...
# 2                     why the fuck is bayless isoing
# 3                        to make her feel threatened
# 4                             dirty southern wankers

# %%
combined = combined[combined["clean_text"].str.len() > 5]
combined = combined.drop_duplicates(subset=["clean_text"])

print(combined.shape)
# Out:
# (85173, 2)

# %%
def preprocess_spacy(text):
    doc = nlp(text)

    tokens = []

    for token in doc:
        if token.is_stop:
            continue

        if token.is_punct:
            continue

        if token.is_space:
            continue

        lemma = token.lemma_.strip()

        if len(lemma) < 3:
            continue

        tokens.append(lemma)

    return " ".join(tokens)

# %%
combined["processed_text"] = combined["clean_text"].progress_apply(preprocess_spacy)
# Out:
# 100%|██████████| 85173/85173 [09:01<00:00, 157.23it/s]

# %%
combined = combined[combined["processed_text"].str.len() > 5]

print(combined.shape)
combined.head()
# Out:
# (82872, 3)
#                                                 text  \
# 0  My favourite food is anything I didn't have to...
# 1  Now if he does off himself, everyone will thin...
# 2                     WHY THE FUCK IS BAYLESS ISOING
# 3                        To make her feel threatened
# 4                             Dirty Southern Wankers
#
#                                           clean_text  \
# 0  my favourite food is anything i didn t have to...
# 1  now if he does off himself everyone will think...
# 2                     why the fuck is bayless isoing
# 3                        to make her feel threatened
# 4                             dirty southern wankers
#
#                                       processed_text
# 0                           favourite food didn cook
# 1  think have laugh screw people instead actually...
# 2                                fuck bayless isoing
# 3                                      feel threaten
# 4                              dirty southern wanker

# %%
import os

os.makedirs("../data/processed", exist_ok=True)

combined.to_csv("../data/processed/final_corpus.csv", index=False)

print("saved")
# Out:
# saved

# %%
combined[["text", "processed_text"]].sample(5)
# Out:
#                                                     text  \
# 49417           I hope you get the help you need. Truly.
# 36158                                 He took it too far
# 2349              Taking this way farther than needed...
# 4122   Then the argument is entirely wrong. Democrati...
# 57120  I've been trying to maintain my composure in t...
#
#                                           processed_text
# 49417                               hope help need truly
# 36158                                           take far
# 2349                                   take way far need
# 4122   argument entirely wrong democratic socialist c...
# 57120  try maintain composure face disagreement ackno...
